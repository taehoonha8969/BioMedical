# %% [markdown]
# <a href="https://colab.research.google.com/github/taehoonha8969/BioMedical/blob/main/2026_06_22_%ED%95%A8%EC%88%98_%EC%8B%AC%ED%99%94_%EB%A6%AC%EC%8A%A4%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#21-1. 1부터 1000사이에 존재하는 소수들의 개수를 출력해주세요.(개념 : 함수, 반복문, 리턴)

def is_prime_number(num):
  #소수: 1보다 큰 자연수 중에서 1과 자기 자신만을 약수로 가지는 수
  #1이 입력되면 거짓 반환
  if num <= 1:
    return False

  i = 2 #1은 소수가 아니기 때문에 2부터 시작
  #소수: 1과 자기 자신만 약수, 따라서 자신과 나누는 경우는 제외
  while i < num:
    if num % i == 0:
      #약수가 확인될 경우 거짓을 반환
      return False
    #다음수로 이동
    i += 1
  #약수가 없는 경우 참을 반
  else:
    return True

sum = 0 #소수의 갯수를 저장하는 변수
j = 1

#1부터 1000까지 순차적으로 증가하며 소수인지 확인
while j <= 1000:
  #소수를 찾는 함수가 참이면 소수의 갯수를 1 증가
  if(is_prime_number(j) == True):
    sum += 1

  #다음수로 순차적 증가
  j += 1

print(sum)
# Out:
# 3

# %%
#21-2. 인자로 전달받은 숫자가 10이라고 할 때 1 부터 10 사이에 존재하는 모든 소수를 출력하는 함수 구현

def print_prime_number(num):
  #소수인지 확인하는 함수
  def is_prime_number(num):
    #소수: 1보다 큰 자연수 중에서 1과 자기 자신만을 약수로 가지는 수
    #1이 입력되면 거짓 반환
    if num <= 1:
      return False

    i = 2 #1은 소수가 아니기 때문에 2부터 시작
    #소수: 1과 자기 자신만 약수, 따라서 자신과 나누는 경우는 제외
    while i < num:
      if num % i == 0:
        #약수가 확인될 경우 거짓을 반환
        return False
      #다음수로 이동
      i += 1
    #약수가 없는 경우 참을 반
    else:
      return True

  j = 1

  #2부터 num까지 순차적으로 증가하며 소수인지 확인
  while j <= num:
    #소수이면 그 값을 출력
    if(is_prime_number(j) == True):
      print(j)

    #다음수로 순차적 증가
    j += 1

print_prime_number(10)
# Out:
# 2
# 3
# 5
# 7

# %%
#21-3. 인자로 전달받은 숫자가 10이라고 할때 1부터 10 사이에 존재하는 모든 소수의 개수를 리턴하는 함수 구현

def count_prime_number(num):
  #소수인지 확인하는 함수
  def is_prime_number(num):
    #소수: 1보다 큰 자연수 중에서 1과 자기 자신만을 약수로 가지는 수
    #1이 입력되면 거짓 반환
    if num <= 1:
      return False

    i = 2 #1은 소수가 아니기 때문에 2부터 시작
    #소수: 1과 자기 자신만 약수, 따라서 자신과 나누는 경우는 제외
    while i < num:
      if num % i == 0:
        #약수가 확인될 경우 거짓을 반환
        return False
      #다음수로 이동
      i += 1
    #약수가 없는 경우 참을 반
    else:
      return True

  count = 0 #소수의 갯수를 저장하는 변수
  j = 1

  #2부터 num까지 순차적으로 증가하며 소수인지 확인
  while j <= num:
    #소수이면 갯수를 1 증가
    if(is_prime_number(j) == True):
      count += 1

    #다음수로 순차적 증가
    j += 1

  #저장된 소수의 갯수를 반환
  return count

count_prime_number(10)
# Out:
# 4

# %%
#21-4. 인자로 전달받은 숫자가 10이라고 할때 1부터 10 사이에 존재하는 모든 소수의 합을 리턴하는 함수 구현

def sum_prime_number(num):
  #소수인지 확인하는 함수
  def is_prime_number(num):
    #소수: 1보다 큰 자연수 중에서 1과 자기 자신만을 약수로 가지는 수
    #1이 입력되면 거짓 반환
    if num <= 1:
      return False

    i = 2 #1은 소수가 아니기 때문에 2부터 시작
    #소수: 1과 자기 자신만 약수, 따라서 자신과 나누는 경우는 제외
    while i < num:
      if num % i == 0:
        #약수가 확인될 경우 거짓을 반환
        return False
      #다음수로 이동
      i += 1
    #약수가 없는 경우 참을 반환
    else:
      return True

  sum = 0 #소수의 합을 저장하는 변수
  j = 1

  #2부터 num까지 순차적으로 증가하며 소수인지 확인
  while j <= num:
    #소수이면 합을 더함
    if(is_prime_number(j) == True):
      sum += j

    #다음수로 순차적 증가
    j += 1

  #저장된 소수의 합을 반환
  return sum

sum_prime_number(10)
# Out:
# 17

# %%
#22-1. 출력 => 1020
a = 10
b = 20

#1. int형의 변수를 str형으로 변환하여 더함
print(str(a) + str(b))
#2. print 함수에서 분리 매개변수인 sep를 공백으로 설정
#print(*args, sep=' ', end='\n', file=None, flush=False), sep: default a space
#print(a, b, sep='')
# Out:
# 1020

# %%
#22-2. 출력 9
a = '3'
b = '6'

#str형의 변수를 int형으로 변환
print(int(a) + int(b))
# Out:
# 9

# %%
#22-3. 출력 9.2
a = '3.1'
b = '6.1'

#str형의 변수를 float형으로 변환
print(float(a) + float(b))
# Out:
# 9.2

# %%
#22-4. 출력 9
a = '3.1'
b = '6.1'

#str형의 변수를 float형으로 변환
#float형의 값을 int형으로 출력 설정하여 소수점을 출력하지 않음
print("%d" %(float(a) + float(b)))
#'3.1'을 int로 바로 변경하면 에러 발생
#print("%d"%(int(a) + float(b)))

# a = float(a)
# b = float(b)
# print(int(a) + int(b))
# Out:
# 9

# %%
#25-1. 리스트에 순서대로 2, 1, 5, 6, 7를 한번에 담아주세요.
#25-2. 비어있는 리스트를 만들고, 순서대로 2, 1, 5, 6, 7를 하나씩 담아주세요.

num = [2, 1, 5, 6, 7]
num2 = []
num2 = num

print(num2)
# Out:
# [2, 1, 5, 6, 7]

# %%
#25-3. 리스트에 순서대로 '월', '화', '수', '목', '금'을 한번에 담아주세요. 그리고 '토', '일' 을 순서대로 추가해주세요.
week = ['월', '화', '수', '목', '금']
week.append('토')
week.append('일')

print(week)
# Out:
# ['월', '화', '수', '목', '금', '토', '일']

# %%
#25-4. 리스트에 순서대로 '월', '화', '수', '목', '금'을 한번에 담아주세요. 그리고 '토', '일' 을 담은 리스트를 만들고 2개의 리스트 합쳐서 새로운 리스트를 만들어주세요.
week1 = ['월', '화', '수', '목', '금']
week2 = ['토', '일']
week3 = week1 + week2
print(week3)
# Out:
# ['월', '화', '수', '목', '금', '토', '일']

# %%
#25-5. 리스트에 순서대로 '월', '화', '수', '목', '금'을 한번에 담아주세요. 그리고 '+=' 연산자를 이용해서 '토', '일' 을 한번에 추가해주세요.
week = ['월', '화', '수', '목', '금']
week += ['토', '일']
print(week)
# Out:
# ['월', '화', '수', '목', '금', '토', '일']

# %%
#25-6. 리스트에 순서대로 '월', '화', '수', '목', '금'을 한번에 담아주세요. 그리고 가장 처음 요소를 출력해주세요.
week = ['월', '화', '수', '목', '금']
print(week[0])
# Out:
# 월

# %%
#25-7. 리스트에 순서대로 '월', '화', '수', '목', '금'을 한번에 담아주세요. 그리고 가장 마지막 요소를 출력해주세요.
week = ['월', '화', '수', '목', '금']
print(week[-1])
# Out:
# 금

# %%
#25-8. 리스트에 순서대로 '월', '화', '수', '목', '금'을 한번에 담아주세요. 그리고 가장 마지막에서 2번째 요소를 출력해주세요.
week = ['월', '화', '수', '목', '금']
print(week[-2])
# Out:
# 목

# %%
#25-9. 리스트에 순서대로 '월', '화', '수', '목', '금'을 한번에 담아주세요. 그리고 while문을 이용해서 요소 전부 출력해주세요.
week = ['월', '화', '수', '목', '금']
i = 0 #리스트의 시작은 0
#리스트의 길이를 계산
while i < len(week):
  print(week[i], end=' ')
  i += 1
  if i == len(week):
    break
# Out:
# 월 화 수 목 금

# %%
#25-10. 리스트에 순서대로 '월', '화', '수', '목', '금'을 한번에 담아주세요. 그리고 while문을 이용해서 요소 전부 역순으로 출력해주세요.
week = ['월', '화', '수', '목', '금']
#리스트의 길이를 계산
i = len(week)
while i >= 0:
  #리스트의 역순으로 출력
  print(week[i-1], end=' ')
  i -= 1
  if i == 0:
    break
# Out:
# 금 목 수 화 월
